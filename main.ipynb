# %%
# Importar bibliotecas necesarias
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Modulos propios de utileria
# %load_ext autoreload
# %autoreload 2
import modules.feature_engineering_utils as feature

# %%
#Variable Globales
dataset_url = 'dataset/UDB_base2.csv'

# %%
# Cargar el dataset seleccionado
df = pd.read_csv(dataset_url)

# Mostrar primeras filas e información
print(df.shape)
df.head()
# Out:
# (774523, 19)
#    id_comercio          company_created_at             categoria  is_taxpayer  \
# 0        21981  2024-04-25 19:18:46.102734  Educación y deportes         True
# 1        21981  2024-04-25 19:18:46.102734  Educación y deportes         True
# 2        21981  2024-04-25 19:18:46.102734  Educación y deportes         True
# 3        21981  2024-04-25 19:18:46.102734  Educación y deportes         True
# 4        21981  2024-04-25 19:18:46.102734  Educación y deportes         True
#
#   tipo_comercio banco_afiliacion_comercio  id_transaccion  monto  \
# 0       Society            CREDICORPBANK          2359347  37430
# 1       Society            CREDICORPBANK          2359522  37430
# 2       Society            CREDICORPBANK          2363347  31500
# 3       Society            CREDICORPBANK          2363503  29925
# 4       Society            CREDICORPBANK          2363771  37430
#
#           currency_iso tipo_transaccion modo_lectura  pos_id modelo_pos  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774523 entries, 0 to 774522
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   id_comercio                774523 non-null  int64
#  1   company_created_at         774523 non-null  object
#  2   categoria                  774523 non-null  object
#  3   is_taxpayer                774523 non-null  bool
#  4   tipo_comercio              774523 non-null  object
#  5   banco_afiliacion_comercio  772379 non-null  object
#  6   id_transaccion             774523 non-null  int64
#  7   monto                      774523 non-null  int64
#  8   currency_iso               774523 non-null  object
#  9   tipo_transaccion           774523 non-null  object
#  10  modo_lectura               707389 non-null  object
#  11  pos_id                     707389 non-null  float64
#  12  modelo_pos                 734788 non-null  object
# ...

# %%
df_feature = df[['T','RH','AH']]
feature.correlation_analysis(df_feature)

# %%
sns.pairplot(df_feature)

# %%
feature.boxplot_analysis(df_feature)
