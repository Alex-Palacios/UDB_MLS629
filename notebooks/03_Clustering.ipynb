# %% [markdown]
# # **Aplicación de Clustering**
#
# En este apartado se implementará al menos dos algoritmos de clustering distintos (pudiendo elegir entre K-means, DBSCAN, Agglomerative Clustering, Gaussian Mixture Models, Spectral Clustering, BIRCH, HDBSCAN, etc.), realizando una evaluación exhaustiva mediante múltiples métricas internas (como silueta, Davies-Bouldin, Calinski-Harabasz, etc.), además de proporcionar una interpretación detallada de los clusters obtenidos en el contexto del dominio de aplicación.

# %%
#Importar librerias a utilizar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar el dataset
df = pd.read_csv('../dataset/Fintech_Features.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403535 entries, 0 to 403534
# Data columns (total 28 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   is_taxpayer                               403535 non-null  int64
#  1   lat                                       403535 non-null  float64
#  2   long                                      403535 non-null  float64
#  3   monto_log                                 403535 non-null  float64
#  4   mes                                       403535 non-null  int64
#  5   dia_semana                                403535 non-null  int64
#  6   hora                                      403535 non-null  int64
#  7   antiguedad_dias_comercio                  403535 non-null  int64
#  8   tipo_comercio_Natural person              403535 non-null  int64
#  9   tipo_comercio_Society                     403535 non-null  int64
# ...

# %%
df.head()
# Out:
#    is_taxpayer       lat      long  monto_log  mes  dia_semana  hora  \
# 0            1  8.989382 -79.53676   4.322011    8           4    12
# 1            1  8.989382 -79.53676   4.322011    8           4     0
# 2            1  8.989382 -79.53676   4.151984    8           4    22
# 3            1  8.989382 -79.53676   4.101486    8           4     7
# 4            1  8.989382 -79.53676   4.322011    8           4     0
#
#    antiguedad_dias_comercio  tipo_comercio_Natural person  \
# 0                       462                             0
# 1                       462                             0
# 2                       463                             0
# 3                       462                             0
# 4                       462                             0
#
#    tipo_comercio_Society  ...  tipo_transaccion_REUSABLE-WITH-AMOUNT  \
# 0                      1  ...                                      0
# ...

# %% [markdown]
# # ** Clustering con K-Mean**
#
# En este apartado se aplicará técnica de K-Mean para la clusterización al dataset de features obtenido del EDA anterior

# %% [markdown]
# # ** Clustering con DBSCAN**
#
# En este apartado se aplicará técnica de K-Mean para la clusterización al dataset de features obtenido del EDA anterior
